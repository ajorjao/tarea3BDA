# %% [markdown]
# <i><h2 style="font-family:serif;font-size:250%; text-align:center;color:#004d80"> Tarea III BDA: Neo4j</h2></i>
# <i><h3 style="font-family:serif;font-size:100%; text-align:center;color:#FFFFF"> Jorge Caullán </h3></i></i>
# <i><h3 style="font-family:serif;font-size:100%; text-align:center;color:#FFFFF"> Miguel Huichaman </h3></i></i>
# <i><h3 style="font-family:serif;font-size:100%; text-align:center;color:#FFFFF"> Ignacio Loayza</h3></i></i>
#
# # Introducción
#
# A continuación se presenta el análisis de dos conjuntos de datos almacenados en el motor de base de datos `Neo4j`.
# Los dos conjuntos a analizar corresponden a la red del metro de Santiago de Chile, donde los nodos corresponden a las estacione y las relaciones entre nodos son hechas en base a la conexión directa entras las estaciones.
#
#
#
# ### inicialización de la base de datos
# nota: si se tiene problemas para conectar a neo4j desde el navegador, probar
# * host: bolt://localhost:7687
# * usuario: neo4j
# * password: neo4j
#
# 1) si funciona, pedira cambiar el pass: poner cualquier cosa y usar como comando en el navegador
#     * :server change-password
#     * despues volver al password neo4j
#
# 2) si hay problemas, usar desde la consola donde esta el docker:
#     * docker-compose exec neo4j bash
#     * neo4j-admin set-initial-password neo4j
#
#     y reintentar lo anterior
#
# librerias requeridas:
# * pip install py2neo

# %%
from pprint import pprint
from py2neo import Graph, Node, Relationship, NodeMatcher

# conectarse
graph = Graph("bolt://localhost:7687", auth=("neo4j", "neo4j"))

# graph.delete_all()

# %% [markdown]
# ## I) Enrutamiento
#
# > ### Ingestión de los datos hacia la base de datos

# %%
import json
with open('Santiago_de_Chile.json', encoding='utf-8') as fh:
    metros = json.load(fh)

matcher = NodeMatcher(graph)

for metro in metros:
    current_station_node = matcher.match("Station", name=metro['station']).first()
    if current_station_node:
        if current_station_node['line'] != metro['line']:
            current_station_node['line'] = '{},{}'.format(current_station_node['line'], metro['line'])
            graph.push(current_station_node)
    else:
        current_station_node = Node("Station", name=metro['station'], line=metro['line'])
        graph.create(current_station_node)

    if metro['previous'] != None:
        previous_node = matcher.match("Station", name=metro['previous']['station']).first()
        graph.create(Relationship(previous_node, "CONNECT", current_station_node, distance=metro['previous']['distance_in_meters']))
    if metro['next'] != None:
        next_node = matcher.match("Station", name=metro['next']['station']).first()
        if next_node:
            graph.create(Relationship(current_station_node, "CONNECT", next_node, distance=metro['next']['distance_in_meters']))

# %% [markdown]
# > ### 1) Seleccione y muestre todas las estaciones correspondientes a una lı́nea de metro (Excluyendo lı́nea 4A).
#
# En este caso, recuperaremos todas las estaciones correspondientes a la linea `L4` que además no estén en la línea ´L4A´:

# %%
required_line = 'L4'

query = """
MATCH (n)
WHERE n.line contains {required_line} AND (not(n.line contains 'L4A'))
RETURN n
"""

data = graph.run(query, required_line=required_line)
print('Estaciones en {} y no en L4:\n'.format(required_line))
for d in data:
    print(dict(d)['n']['name'])
# Out:
# Estaciones en L4 y no en L4:
#
# Tobalaba
# Los Orientales
# Grecia
# Los Presidentes
# Quilín
# Las Torres
# Macul
# Vicente Valdés
# Rojas Magallanes
# Trinidad
# San José de la Estrella
# Los Quillayes
# Elisa Correa
# Plaza Egaña
# Cristóbal Colón
# Francisco Bilbao
# Príncipe de Gales
# Simón Bolívar
# Las Mercedes
# Plaza de Puente Alto
# Hospital Sótero del Río
# Protectora de la Infancia

# %% [markdown]
# <img src='estaciones L4 sin L4A.png'>

# %% [markdown]
# > ### 2) Muestre las 10 estaciones mas cercanas entre sí
#
# Primero, se recuperan todos aquellos objetos que conectan con una estación, luego, se filtra solo aquellos atributos relevantes, en nuestro caso, `name` de la primera estación, `distance` que representa el peso de la arista entre las dos estaciones y `name` de la segunda estación. Finalmente, se ordena según `distance` (orden creciente) y se limita el retorno de la consulta a solo 10 elementos:

# %%
query = """
MATCH(first)-[c:CONNECT]->(second:Station)
RETURN first.name, c.distance, second.name 
ORDER BY c.distance 
LIMIT 10
"""

data = graph.run(query)

print('Las estaciones más cercanas entre sí son:\n')
for i, d in enumerate(data):
    data_dict = dict(d)
    print('{3}. {0} y {1}, separadas por un distancia de {2} [m]'.format(data_dict['first.name'],
                                                                data_dict['second.name'],
                                                                data_dict['c.distance'],
                                                                i+1))
# Out:
# Las estaciones más cercanas entre sí son:
#
# 1. La Moneda y Universidad de Chile, separadas por un distancia de 400 [m]
# 2. Los Héroes y La Moneda, separadas por un distancia de 460 [m]
# 3. Universidad de Chile y Santa Lucía, separadas por un distancia de 480 [m]
# 4. Parque Bustamante y Santa Isabel, separadas por un distancia de 500 [m]
# 5. Las Rejas y Ecuador, separadas por un distancia de 520 [m]
# 6. Santa Lucía y Universidad Católica, separadas por un distancia de 530 [m]
# 7. San Alberto Hurtado y Universidad de Santiago, separadas por un distancia de 540 [m]
# 8. Carlos Valdovinos y Camino Agrícola, separadas por un distancia de 540 [m]
# 9. Pedro de Valdivia y Los Leones, separadas por un distancia de 550 [m]
# 10. Unión Latinoamericana y República, separadas por un distancia de 560 [m]

# %% [markdown]
# <img src='10 estaciones mas cercanas.png'>

# %% [markdown]
# > ### 3) Muestre todas las estaciones con combinación.

# %%
query = """
MATCH (n:Station)
WHERE NOT(n.line in ['L1', 'L2', 'L3', 'L4', 'L4A', 'L5', 'L6'])
RETURN n
"""

data = graph.run(query)

for d in data:
    print(dict(d)['n']['name'])
# Out:
# San Pablo
# Baquedano
# Los Héroes
# Universidad de Chile
# Los Leones
# Tobalaba
# Puente Cal y Canto
# Santa Ana
# Franklin
# La Cisterna
# Irarrázaval
# Ñuñoa
# Plaza de Armas
# Vicuña Mackenna
# Vicente Valdés
# Plaza Egaña
# Ñuble

# %% [markdown]
# <img src='combinaciones.png'>

# %% [markdown]
# > ### 4) Busque la ruta mas corta entre una estacion de metro y la estacion Camino Agricola, esta ruta debe tener al menos 10 nodos y una combinacion
#
# Utilizaremos como estación base la estación **_"Manuel Montt"_**. Además, pediremos las 2 rutas más cortas inmediatamente. En el caso de la ruta más corta:

# %%
query = """
MATCH (start:Station{name:"Manuel Montt"}), (end:Station{name:"Camino Agrícola"})
CALL algo.kShortestPaths.stream(start, end, 2, "distance")
YIELD index, nodeIds, costs
RETURN [node in algo.getNodesById(nodeIds) | node.name] AS places,
       costs,
       reduce(acc = 0.0, cost in costs | acc + cost) AS totalCost
"""

data_shortest, data_2_shortest = graph.run(query)

for i, d in enumerate(dict(data_shortest)['places']):
    print('{0}º {1}'.format(i+1, d))
print('\nLargo total de la ruta más corta (Manuel Montt -> Camino Agricola): {}[m]'.format(
                                                                            data_shortest['totalCost']))
# Out:
# 1º Manuel Montt
# 2º Salvador
# 3º Baquedano
# 4º Parque Bustamante
# 5º Santa Isabel
# 6º Irarrázaval
# 7º Ñuble
# 8º Rodrigo de Araya
# 9º Carlos Valdovinos
# 10º Camino Agrícola
#
# Largo total de la ruta más corta (Manuel Montt -> Camino Agricola): 8050.0[m]

# %% [markdown]
# > ### 5) Considere que ya no puede realizar esa combinacion, busque la siguiente ruta mas corta
# La segunda ruta más corta es:

# %%
for i, d in enumerate(dict(data_2_shortest)['places']):
    print('{0}º {1}'.format(i+1, d))
print('\nLargo total de la segunda ruta más corta (Manuel Montt -> Camino Agricola): {}[m]'.format(
                                                                                    data_2_shortest['totalCost']))
# Out:
# 1º Manuel Montt
# 2º Pedro de Valdivia
# 3º Los Leones
# 4º Inés de Suárez
# 5º Ñuñoa
# 6º Estadio Nacional
# 7º Ñuble
# 8º Rodrigo de Araya
# 9º Carlos Valdovinos
# 10º Camino Agrícola
#
# Largo total de la segunda ruta más corta (Manuel Montt -> Camino Agricola): 11050.0[m]

# %% [markdown]
# ## II) Centralidad y Comunidades
# > ### Ingestión de los datos hacia la base de datos

# %% [markdown]
# Debido a la gran cantidad de datos que posee cada uno de los datasets, se opta por utilizar unicamente 10000 datos de cada uno ya que de lo contrario, la demora para agregar los datos era demaciada.
#
# Habiendo definido esto, el codigo que se utiliza para agregar los datos es el siguiente

# %%
graph = Graph("bolt://localhost:7687", auth=("neo4j", "neo4j"))
# graph.delete_all()

matcher = NodeMatcher(graph)
c=0

# f = open('../soc-redditHyperlinks-title.tsv', 'r')
f = open('soc-redditHyperlinks-body.tsv', 'r')
f.readline() #para saltar la primera linea
all_lines = f.readlines()
f.close()

# total_lines = len(all_lines)
total_lines = 10000
post_ids = []

for row in all_lines:
    if c % (total_lines/100) == 0:
        print("progress:", c/float(total_lines)*100)
        
    #cada row es una referencia entre 2 subredits
    #el post id se puede repetir y las propeties son las mismas cuando se repiten
    row = row.replace('\n','').split('\t')
    if row[2] in post_ids:
        positive = 0
        negative = 0
    else:
        post_ids.append(row[2])
        if row[4] == '1':
            positive = 1
            negative = 0
        else:
            positive = 0
            negative = 1
    
    #crear subreddits si no existen
    subreddit_node = matcher.match("Subreddit", name=row[0]).first()
    if subreddit_node: #agregar el sentimiento del post al subredit
        subreddit_node['positives'] = subreddit_node['positives']+positive
        subreddit_node['negatives'] = subreddit_node['negatives']+negative
        graph.push(subreddit_node)
    else:
        subreddit_node = Node("Subreddit", name=row[0], positives=positive, negatives=negative)
        graph.create(subreddit_node)
        
    subreddit_hiperlink_node = matcher.match("Subreddit", name=row[1]).first()
    if not subreddit_hiperlink_node:
        subreddit_hiperlink_node = Node("Subreddit", name=row[1], positives=0, negatives=0)
        graph.create(subreddit_hiperlink_node)
    
    #relacion entre ambos subreddits
    graph.create(Relationship(subreddit_node, "REFERENCE", subreddit_hiperlink_node))
    
    c+=1
    if c==total_lines:
        break
# Out:
# progress: 0.0
# progress: 1.0
# progress: 2.0
# progress: 3.0
# progress: 4.0
# progress: 5.0
# progress: 6.0
# progress: 7.000000000000001
# progress: 8.0
# progress: 9.0
# progress: 10.0
# progress: 11.0
# progress: 12.0
# progress: 13.0
# progress: 14.000000000000002
# progress: 15.0
# progress: 16.0
# progress: 17.0
# progress: 18.0
# progress: 19.0
# progress: 20.0
# progress: 21.0
# progress: 22.0
# progress: 23.0
# progress: 24.0
# progress: 25.0
# progress: 26.0
# progress: 27.0
# progress: 28.000000000000004
# progress: 28.999999999999996
# progress: 30.0
# progress: 31.0
# progress: 32.0
# progress: 33.0
# progress: 34.0
# progress: 35.0
# progress: 36.0
# progress: 37.0
# progress: 38.0
# progress: 39.0
# progress: 40.0
# progress: 41.0
# progress: 42.0
# progress: 43.0
# progress: 44.0
# progress: 45.0
# progress: 46.0
# progress: 47.0
# progress: 48.0
# progress: 49.0
# progress: 50.0
# progress: 51.0
# progress: 52.0
# progress: 53.0
# progress: 54.0
# progress: 55.00000000000001
# progress: 56.00000000000001
# progress: 56.99999999999999
# progress: 57.99999999999999
# progress: 59.0
# progress: 60.0
# progress: 61.0
# progress: 62.0
# progress: 63.0
# progress: 64.0
# progress: 65.0
# progress: 66.0
# progress: 67.0
# progress: 68.0
# progress: 69.0
# progress: 70.0
# progress: 71.0
# progress: 72.0
# progress: 73.0
# progress: 74.0
# progress: 75.0
# progress: 76.0
# progress: 77.0
# progress: 78.0
# progress: 79.0
# progress: 80.0
# progress: 81.0
# progress: 82.0
# progress: 83.0
# progress: 84.0
# progress: 85.0
# progress: 86.0
# progress: 87.0
# progress: 88.0
# progress: 89.0
# progress: 90.0
# progress: 91.0
# progress: 92.0
# progress: 93.0
# progress: 94.0
# progress: 95.0
# progress: 96.0
# progress: 97.0
# progress: 98.0
# progress: 99.0

# %% [markdown]
# > ### 1) Detectar comunidades automáticamente, determine el tema de 3 de ellas y liste sus miembros.

# %% [markdown]
# Para esta pregunta, debido a la ambiguedad del concepto "comunidad", se utilizara como supuesto que una comunidad es un conjunto de subreddits que a su vez estan referenciados por al menos 5 otros subreddits.
#
# A partir de esto, si utilizamos la siguiente consulta, podemos encontrar 3 comunidades y sus miembros:

# %%
query = """
MATCH (n:Subreddit)-[:REFERENCE]->(m)
WITH m, collect(n) as subsubreddits
WHERE size(subsubreddits) > 5
return m, subsubreddits limit 3
"""

data = graph.run(query)

comunidades = {}
for d in data:
    comunidades[d[0]['name']] = []
    for subsub in d[1]:
        comunidades[d[0]['name']].append(subsub['name'])
        
pprint(comunidades)
# Out:
# {'battlefield_4': ['xboxone',
#                    'ps4',
#                    'bestof',
#                    'subredditdrama',
#                    'gaming',
#                    'bf4server',
#                    'mwo',
#                    'psbf',
#                    'purebattlefield'],
#  'games': ['battlefield_4',
#            'bestof',
#            'subredditdrama',
#            'circlebroke2',
#            'shitstatistssay',
#            'starcraft',
#            'gaming',
#            'shitredditsays',
#            'pcmasterrace',
#            'truestl',
#            'worstof',
#            'srsgaming',
#            'steam',
#            'elderscrollsonline',
#            'fallout',
#            'eve',
#            'playrust',
#            'cynicalbrit',
#            'credditgaming',
#            'evedreddit',
#            'overgrowth',
#            'stargate',
#            'starcraft2arcade'],
#  'ps4': ['xboxone',
#          'quityourbullshit',
#          'shitredditsays',
#          'pcmasterrace',
#          'firstworldanarchists',
#          'vita',
#          'bestbuy',
#          'assassincommunity',
#          'ps4mods']}

# %% [markdown]
# <img src='comunidades.png'>

# %% [markdown]
# <img src='louvain_1.png'>

# %% [markdown]
# Hay una gran comunidad centrada alrededor del hub _'Gaming'_, observandose dos sub-comunidades de _'ps4'_ y 'battlefield_4'. Además, utilizando el algoritmo de detección de comunidades de Louvaina que forma parte del repertorio de `Neo4j`, se observa en la segunda imagen dos comunidades más: 'Christianity' y 'AskHistorians'

# %% [markdown]
# > ### 2) Encontrar los subreddits mas referenciados dentro de 3 comunidades diferentes. Que tienen en comun?(centralidad).

# %%
query = """
MATCH (n:Subreddit)-[:REFERENCE]->(m) 
return m, collect(n) as subsubreddits
order by size(subsubreddits) desc limit 3
"""

data = graph.run(query)

subreddits = {}
for d in data:
    subreddits[d[0]['name']] = []
    for subsub in d[1]:
        subreddits[d[0]['name']].append(subsub)
pprint(subreddits)
# Out:
# {'askreddit': [{'name': 'battlefield_4',
#                 'negatives': 0,
#                 'positives': 5},
#                (_149:Subreddit {name: 'depthhub', negatives: 8, positives: 53}),
#                {'name': 'panichistory',
#                 'negatives': 6,
#                 'positives': 35},
#                (_158:Subreddit {name: 'wtf', negatives: 1, positives: 7}),
#                {'name': 'fitnesscirclejerk',
#                 'negatives': 19,
#                 'positives': 87},
#                {'name': 'bestoftldr',
#                 'negatives': 8,
#                 'positives': 25},
#                {'name': 'quityourbullshit',
#                 'negatives': 14,
#                 'positives': 22},
#                (_175:Subreddit {name: 'funny', negatives: 1, positives: 19}),
#                (_178:Subreddit {name: 'nofap', negatives: 0, positives: 11}),
#                {'name': 'switcharoo',
#                 'negatives': 5,
#                 'positives': 115},
#                (_183:Subreddit {name: 'bitcoin', negatives: 2, positives: 48}),
#                {'name': 'subredditdrama',
#                 'negatives': 216,
#                 'positives': 360},
#                {'name': 'conspiracy',
#                 'negatives': 5,
#                 'positives': 56},
#                {'name': 'agitation',
#                 'negatives': 8,
#                 'positives': 53},
#                {'name': 'magicskyfairy',
#                 'negatives': 2,
#                 'positives': 19},
#                {'name': 'circlebroke2',
#                 'negatives': 27,
#                 'positives': 74},
#                (_213:Subreddit {name: 'trees', negatives: 0, positives: 29}),
#                {'name': 'technology',
#                 'negatives': 0,
#                 'positives': 20},
#                {'name': 'examplesofevil',
#                 'negatives': 0,
#                 'positives': 33},
#                {'name': 'totallystraight',
#                 'negatives': 0,
#                 'positives': 3},
#                (_225:Subreddit {name: 'metahub', negatives: 0, positives: 8}),
#                {'name': 'todayilearned',
#                 'negatives': 6,
#                 'positives': 32},
#                (_229:Subreddit {name: 'vegan', negatives: 1, positives: 8}),
#                {'name': 'shitstatistssay',
#                 'negatives': 17,
#                 'positives': 93},
#                {'name': 'shitamericanssay',
#                 'negatives': 14,
#                 'positives': 71},
#                (_245:Subreddit {name: 'cfb', negatives: 0, positives: 8}),
#                {'name': 'christianity',
#                 'negatives': 0,
#                 'positives': 13},
#                {'name': 'badhistory',
#                 'negatives': 10,
#                 'positives': 25},
#                (_269:Subreddit {name: 'dogecoin', negatives: 3, positives: 94}),
#                {'name': 'metacanada',
#                 'negatives': 5,
#                 'positives': 40},
#                {'name': 'notcirclejerk',
#                 'negatives': 0,
#                 'positives': 40},
#                (_279:Subreddit {name: 'atheism', negatives: 2, positives: 24}),
#                (_301:Subreddit {name: 'prolife', negatives: 0, positives: 9}),
#                {'name': 'thathappened',
#                 'negatives': 10,
#                 'positives': 36},
#                (_306:Subreddit {name: 'seduction', negatives: 0, positives: 7}),
#                {'name': 'photoshopbattles',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'mensrights',
#                 'negatives': 5,
#                 'positives': 22},
#                {'name': 'conservative',
#                 'negatives': 0,
#                 'positives': 9},
#                {'name': 'libertarian',
#                 'negatives': 6,
#                 'positives': 23},
#                {'name': 'karmaconspiracy',
#                 'negatives': 6,
#                 'positives': 18},
#                {'name': 'titlegore',
#                 'negatives': 0,
#                 'positives': 116},
#                (_325:Subreddit {name: 'travel', negatives: 0, positives: 4}),
#                {'name': 'retiredgif',
#                 'negatives': 3,
#                 'positives': 76},
#                {'name': 'gmomyths',
#                 'negatives': 13,
#                 'positives': 23},
#                (_343:Subreddit {name: 'cringe', negatives: 2, positives: 11}),
#                {'name': 'anarchism',
#                 'negatives': 1,
#                 'positives': 15},
#                (_352:Subreddit {name: 'gaming', negatives: 0, positives: 39}),
#                {'name': 'badlinguistics',
#                 'negatives': 5,
#                 'positives': 48},
#                (_358:Subreddit {name: 'australia', negatives: 0, positives: 7}),
#                {'name': 'globaloffensive',
#                 'negatives': 0,
#                 'positives': 4},
#                {'name': 'thebluepill',
#                 'negatives': 10,
#                 'positives': 36},
#                {'name': 'vegetarian',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'teenagers',
#                 'negatives': 1,
#                 'positives': 10},
#                {'name': 'againstmensrights',
#                 'negatives': 5,
#                 'positives': 8},
#                (_377:Subreddit {name: 'socialism', negatives: 1, positives: 8}),
#                {'name': 'badphilosophy',
#                 'negatives': 7,
#                 'positives': 38},
#                {'name': 'conspiratard',
#                 'negatives': 10,
#                 'positives': 60},
#                {'name': 'shitredditsays',
#                 'negatives': 17,
#                 'positives': 107},
#                (_389:Subreddit {name: 'woahdude', negatives: 0, positives: 7}),
#                (_393:Subreddit {name: 'feminism', negatives: 1, positives: 5}),
#                {'name': 'bad_religion',
#                 'negatives': 1,
#                 'positives': 8},
#                {'name': 'vegetarianism',
#                 'negatives': 0,
#                 'positives': 1},
#                (_415:Subreddit {name: 'adviceof', negatives: 0, positives: 20}),
#                (_416:Subreddit {name: 'books', negatives: 0, positives: 12}),
#                {'name': 'pcmasterrace',
#                 'negatives': 1,
#                 'positives': 25},
#                {'name': 'shitpoliticssays',
#                 'negatives': 1,
#                 'positives': 14},
#                {'name': 'circlebroke',
#                 'negatives': 4,
#                 'positives': 5},
#                {'name': 'mylittleandysonic1',
#                 'negatives': 2,
#                 'positives': 13},
#                {'name': 'lewronggeneration',
#                 'negatives': 4,
#                 'positives': 16},
#                {'name': 'decidingtobebetter',
#                 'negatives': 0,
#                 'positives': 13},
#                {'name': 'getmotivated',
#                 'negatives': 0,
#                 'positives': 6},
#                (_450:Subreddit {name: 'animation', negatives: 0, positives: 3}),
#                {'name': 'liverpoolfc',
#                 'negatives': 1,
#                 'positives': 7},
#                (_482:Subreddit {name: 'zen', negatives: 0, positives: 1}),
#                (_483:Subreddit {name: 'truestl', negatives: 1, positives: 8}),
#                (_485:Subreddit {name: 'murica', negatives: 8, positives: 22}),
#                (_500:Subreddit {name: 'music', negatives: 0, positives: 13}),
#                (_516:Subreddit {name: 'math', negatives: 1, positives: 2}),
#                (_519:Subreddit {name: 'exjw', negatives: 0, positives: 8}),
#                {'name': 'firstworldanarchists',
#                 'negatives': 0,
#                 'positives': 16},
#                {'name': 'androidcirclejerk',
#                 'negatives': 4,
#                 'positives': 15},
#                (_530:Subreddit {name: 'verypunny', negatives: 0, positives: 5}),
#                (_531:Subreddit {name: 'shitpost', negatives: 3, positives: 29}),
#                {'name': 'sanantonio',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'imgoingtohellforthis',
#                 'negatives': 1,
#                 'positives': 9},
#                {'name': 'hiphopcirclejerk',
#                 'negatives': 7,
#                 'positives': 26},
#                {'name': 'anarcho_capitalism',
#                 'negatives': 3,
#                 'positives': 37},
#                {'name': 'trailerparkboys',
#                 'negatives': 1,
#                 'positives': 2},
#                {'name': 'unexpected',
#                 'negatives': 1,
#                 'positives': 8},
#                {'name': 'moviescirclejerk',
#                 'negatives': 2,
#                 'positives': 15},
#                {'name': 'relevantxkcd',
#                 'negatives': 0,
#                 'positives': 4},
#                (_592:Subreddit {name: 'love', negatives: 0, positives: 1}),
#                {'name': 'goldredditsays',
#                 'negatives': 6,
#                 'positives': 24},
#                (_601:Subreddit {name: 'economics', negatives: 0, positives: 8}),
#                (_609:Subreddit {name: 'worstof', negatives: 3, positives: 15}),
#                (_612:Subreddit {name: 'iwantout', negatives: 0, positives: 2}),
#                (_619:Subreddit {name: 'teenguide', negatives: 0, positives: 9}),
#                {'name': 'beetlejuicing',
#                 'negatives': 3,
#                 'positives': 4},
#                {'name': 'wtfdidijustread',
#                 'negatives': 3,
#                 'positives': 16},
#                (_664:Subreddit {name: 'buffy', negatives: 0, positives: 1}),
#                (_678:Subreddit {name: 'nascar', negatives: 0, positives: 2}),
#                (_695:Subreddit {name: 'toronto', negatives: 0, positives: 7}),
#                (_705:Subreddit {name: 'basoran', negatives: 0, positives: 3}),
#                {'name': 'historynetwork',
#                 'negatives': 0,
#                 'positives': 12},
#                {'name': 'evenwithcontext',
#                 'negatives': 5,
#                 'positives': 13},
#                (_753:Subreddit {name: 'military', negatives: 1, positives: 2}),
#                {'name': 'muhfeelings',
#                 'negatives': 3,
#                 'positives': 2},
#                {'name': 'theredpill',
#                 'negatives': 3,
#                 'positives': 7},
#                {'name': 'singularity',
#                 'negatives': 0,
#                 'positives': 1},
#                (_831:Subreddit {name: 'darksouls', negatives: 0, positives: 1}),
#                (_855:Subreddit {name: 'exmormon', negatives: 1, positives: 22}),
#                {'name': 'bad_cop_no_donut',
#                 'negatives': 0,
#                 'positives': 11},
#                {'name': 'leagueoflegends',
#                 'negatives': 0,
#                 'positives': 5},
#                {'name': 'fatpeoplestories',
#                 'negatives': 1,
#                 'positives': 3},
#                {'name': 'yougottold',
#                 'negatives': 1,
#                 'positives': 5},
#                {'name': 'mlplounge',
#                 'negatives': 0,
#                 'positives': 11},
#                (_907:Subreddit {name: 'tagpro', negatives: 0, positives: 5}),
#                {'name': 'new_right',
#                 'negatives': 1,
#                 'positives': 20},
#                (_919:Subreddit {name: 'incest', negatives: 0, positives: 3}),
#                {'name': 'transphobiaproject',
#                 'negatives': 3,
#                 'positives': 5},
#                (_931:Subreddit {name: 'intp', negatives: 0, positives: 1}),
#                (_933:Subreddit {name: 'test', negatives: 1, positives: 0}),
#                {'name': 'badscience',
#                 'negatives': 1,
#                 'positives': 8},
#                (_955:Subreddit {name: 'gaybros', negatives: 1, positives: 7}),
#                (_956:Subreddit {name: 'itcrowd', negatives: 1, positives: 0}),
#                {'name': 'dumpsterdiving',
#                 'negatives': 0,
#                 'positives': 5},
#                {'name': 'anticonsumption',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'thelastairbender',
#                 'negatives': 0,
#                 'positives': 3},
#                (_997:Subreddit {name: 'babybumps', negatives: 0, positives: 3}),
#                {'name': 'shittydebatecommunism',
#                 'negatives': 4,
#                 'positives': 13},
#                {'name': 'retiredjpg',
#                 'negatives': 0,
#                 'positives': 7},
#                {'name': 'transgender',
#                 'negatives': 0,
#                 'positives': 6},
#                {'name': 'gamegrumps',
#                 'negatives': 1,
#                 'positives': 2},
#                (_1057:Subreddit {name: 'yogscast', negatives: 0, positives: 5}),
#                {'name': 'squaredcircle',
#                 'negatives': 0,
#                 'positives': 8},
#                {'name': 'dogeawards',
#                 'negatives': 1,
#                 'positives': 5},
#                {'name': 'atheismrebooted',
#                 'negatives': 0,
#                 'positives': 2},
#                (_1126:Subreddit {name: 'vlc', negatives: 0, positives: 1}),
#                (_1144:Subreddit {name: 'chibears', negatives: 1, positives: 3}),
#                {'name': 'politicalmoderation',
#                 'negatives': 0,
#                 'positives': 8},
#                (_1162:Subreddit {name: 'outside', negatives: 0, positives: 5}),
#                (_1168:Subreddit {name: 'medicine', negatives: 0, positives: 4}),
#                {'name': 'morbidreality',
#                 'negatives': 0,
#                 'positives': 6},
#                {'name': 'shitredditgilds',
#                 'negatives': 0,
#                 'positives': 9},
#                {'name': 'reddit_silver',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'beercirclejerk',
#                 'negatives': 3,
#                 'positives': 6},
#                {'name': 'gameofthrones',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'eldertrees',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'onetruegod',
#                 'negatives': 1,
#                 'positives': 6},
#                {'name': 'mildlyinfuriating',
#                 'negatives': 2,
#                 'positives': 1},
#                {'name': 'goodshillhunting',
#                 'negatives': 1,
#                 'positives': 6},
#                (_1414:Subreddit {name: 'ainbow', negatives: 1, positives: 8}),
#                {'name': 'youngearthcreationism',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'mechanicadvice',
#                 'negatives': 1,
#                 'positives': 4},
#                (_1520:Subreddit {name: 'teachers', negatives: 0, positives: 2}),
#                (_1529:Subreddit {name: 'bar', negatives: 0, positives: 1}),
#                {'name': 'femradebates',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'wikipedia',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'frugal_jerk',
#                 'negatives': 1,
#                 'positives': 16},
#                (_1608:Subreddit {name: 'seagray', negatives: 0, positives: 5}),
#                {'name': 'crappydesign',
#                 'negatives': 1,
#                 'positives': 2},
#                {'name': 'freedomearth',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'toasterrights',
#                 'negatives': 2,
#                 'positives': 0},
#                (_1653:Subreddit {name: 'survival', negatives: 0, positives: 2}),
#                (_1684:Subreddit {name: 'pornvids', negatives: 0, positives: 1}),
#                {'name': 'runescape',
#                 'negatives': 0,
#                 'positives': 4},
#                (_1712:Subreddit {name: 'zing', negatives: 0, positives: 2}),
#                {'name': 'digitalcartel',
#                 'negatives': 0,
#                 'positives': 6},
#                (_1732:Subreddit {name: 'romania', negatives: 0, positives: 8}),
#                (_1733:Subreddit {name: 'trippy', negatives: 0, positives: 1}),
#                (_1748:Subreddit {name: 'oculus', negatives: 0, positives: 5}),
#                (_1833:Subreddit {name: 'mdma', negatives: 1, positives: 0}),
#                (_1855:Subreddit {name: 'pandr', negatives: 0, positives: 3}),
#                (_1863:Subreddit {name: 'sandiego', negatives: 0, positives: 1}),
#                {'name': 'glutenfree',
#                 'negatives': 1,
#                 'positives': 3},
#                {'name': 'punthreads',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'mynextband',
#                 'negatives': 3,
#                 'positives': 2},
#                {'name': 'funnyandsad',
#                 'negatives': 0,
#                 'positives': 1},
#                (_2041:Subreddit {name: 'forza', negatives: 0, positives: 4}),
#                {'name': 'gabefoundthisonreddit',
#                 'negatives': 0,
#                 'positives': 2},
#                (_2089:Subreddit {name: 'erb', negatives: 0, positives: 1}),
#                (_2091:Subreddit {name: 'sad', negatives: 0, positives: 1}),
#                {'name': 'supernatural',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'srsorwestboro',
#                 'negatives': 2,
#                 'positives': 2},
#                (_2154:Subreddit {name: 'paleo', negatives: 0, positives: 3}),
#                {'name': 'occupywallstreet',
#                 'negatives': 1,
#                 'positives': 4},
#                {'name': 'misanthropy',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'stopsmoking',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'vaccinemyths',
#                 'negatives': 3,
#                 'positives': 6},
#                (_2367:Subreddit {name: 'srsfunny', negatives: 0, positives: 1}),
#                {'name': 'confusedboners',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': '2007scape',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'twobestfriendsplay',
#                 'negatives': 1,
#                 'positives': 0},
#                {'name': 'bigdickproblems',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'jokesofthedadvariety',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'knifeclub',
#                 'negatives': 0,
#                 'positives': 4},
#                {'name': 'forwardsfromgrandma',
#                 'negatives': 0,
#                 'positives': 1},
#                (_2489:Subreddit {name: 'anxiety', negatives: 0, positives: 1}),
#                (_2513:Subreddit {name: 'straya', negatives: 0, positives: 1}),
#                (_2534:Subreddit {name: 'frat', negatives: 0, positives: 1}),
#                (_2560:Subreddit {name: 'lebowski', negatives: 0, positives: 1}),
#                (_2576:Subreddit {name: 'trolling', negatives: 1, positives: 1}),
#                (_2582:Subreddit {name: 'poetry', negatives: 1, positives: 0}),
#                (_2658:Subreddit {name: 'jobs', negatives: 0, positives: 3}),
#                {'name': 'uwmadison',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'funnyfartstories',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'menuitemjerkoff',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'highschool',
#                 'negatives': 0,
#                 'positives': 1},
#                (_2886:Subreddit {name: 'funfacts', negatives: 0, positives: 2}),
#                {'name': 'antimemewatch',
#                 'negatives': 3,
#                 'positives': 0},
#                (_2958:Subreddit {name: 'matt', negatives: 0, positives: 1}),
#                (_2960:Subreddit {name: 'lasvegas', negatives: 0, positives: 1}),
#                (_2976:Subreddit {name: 'redpower', negatives: 0, positives: 1}),
#                (_3045:Subreddit {name: 'firefly', negatives: 1, positives: 3}),
#                {'name': 'pairmaker',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'badgeography',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'stormlight_archive',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'anomaliesunleashed',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'creepiestof',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'syracuseu',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'transspace',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'neverbrokeabone',
#                 'negatives': 0,
#                 'positives': 1},
#                (_3341:Subreddit {name: 'dumb', negatives: 0, positives: 1}),
#                (_3362:Subreddit {name: 'nyto', negatives: 0, positives: 2}),
#                {'name': 'srsredditdrama',
#                 'negatives': 1,
#                 'positives': 2},
#                (_3419:Subreddit {name: 'redacted', negatives: 0, positives: 2}),
#                (_3460:Subreddit {name: 'feels', negatives: 0, positives: 1}),
#                {'name': 'myemotions',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'fortbadgerton',
#                 'negatives': 0,
#                 'positives': 1},
#                (_3487:Subreddit {name: 'finance', negatives: 0, positives: 2}),
#                {'name': '19thworldproblems',
#                 'negatives': 1,
#                 'positives': 0},
#                {'name': 'enlightenedbirdmen',
#                 'negatives': 0,
#                 'positives': 4},
#                (_3499:Subreddit {name: 'biloxi', negatives: 0, positives: 3}),
#                (_3508:Subreddit {name: 'restof', negatives: 0, positives: 1}),
#                {'name': 'spacesquid',
#                 'negatives': 0,
#                 'positives': 1},
#                (_3571:Subreddit {name: 'jewelers', negatives: 0, positives: 1}),
#                {'name': 'facebookgroupchat',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'thevenusproject',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'theydidthemath',
#                 'negatives': 0,
#                 'positives': 2},
#                (_3651:Subreddit {name: 'wwgha', negatives: 0, positives: 1}),
#                {'name': 'viberightisatwat',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'perfectplanet',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'simplegiving',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'rickygervais',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'urbansurvivalism',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'progrockmusic',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'londonontario',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'subsubredditdrama',
#                 'negatives': 0,
#                 'positives': 3},
#                {'name': 'jenniferlawrence',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'multiplemyeloma',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'threadkillers',
#                 'negatives': 0,
#                 'positives': 2},
#                {'name': 'thatdudewithstories',
#                 'negatives': 0,
#                 'positives': 1},
#                (_4091:Subreddit {name: 'gum', negatives: 0, positives: 1}),
#                (_4204:Subreddit {name: 'twitter', negatives: 0, positives: 1}),
#                {'name': 'thanksobama',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'taintperfume',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'thatcouldhavehappened',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'catsstandingup',
#                 'negatives': 0,
#                 'positives': 1},
#                {'name': 'prufrock451',
#                 'negatives': 0,
#                 'positives': 1}],
#  'iama': [(_148:Subreddit {name: 'politics', negatives: 0, positives: 10}),
#           (_149:Subreddit {name: 'depthhub', negatives: 8, positives: 53}),
#           (_153:Subreddit {name: 'panichistory', negatives: 6, positives: 35}),
#           (_158:Subreddit {name: 'wtf', negatives: 1, positives: 7}),
#           (_160:Subreddit {name: 'ps4', negatives: 0, positives: 8}),
#           {'name': 'fitnesscirclejerk',
#            'negatives': 19,
#            'positives': 87},
#           (_167:Subreddit {name: 'soccer', negatives: 1, positives: 11}),
#           (_172:Subreddit {name: 'bestof', negatives: 101, positives: 494}),
#           (_178:Subreddit {name: 'nofap', negatives: 0, positives: 11}),
#           (_181:Subreddit {name: 'switcharoo', negatives: 5, positives: 115}),
#           (_183:Subreddit {name: 'bitcoin', negatives: 2, positives: 48}),
#           {'name': 'subredditdrama',
#            'negatives': 216,
#            'positives': 360},
#           (_185:Subreddit {name: 'nfl', negatives: 2, positives: 13}),
#           (_189:Subreddit {name: 'conspiracy', negatives: 5, positives: 56}),
#           {'name': 'electronic_cigarette',
#            'negatives': 0,
#            'positives': 40},
#           (_213:Subreddit {name: 'trees', negatives: 0, positives: 29}),
#           {'name': 'totallystraight',
#            'negatives': 0,
#            'positives': 3},
#           (_228:Subreddit {name: 'todayilearned', negatives: 6, positives: 32}),
#           (_229:Subreddit {name: 'vegan', negatives: 1, positives: 8}),
#           (_232:Subreddit {name: 'starcitizen', negatives: 0, positives: 1}),
#           {'name': 'edmprodcirclejerk',
#            'negatives': 1,
#            'positives': 17},
#           (_240:Subreddit {name: 'mindcrack', negatives: 0, positives: 4}),
#           {'name': 'shitstatistssay',
#            'negatives': 17,
#            'positives': 93},
#           {'name': 'shitamericanssay',
#            'negatives': 14,
#            'positives': 71},
#           (_248:Subreddit {name: 'christianity', negatives: 0, positives: 13}),
#           (_249:Subreddit {name: 'nerdcubed', negatives: 0, positives: 1}),
#           (_265:Subreddit {name: 'boston', negatives: 0, positives: 2}),
#           (_269:Subreddit {name: 'dogecoin', negatives: 3, positives: 94}),
#           (_278:Subreddit {name: 'notcirclejerk', negatives: 0, positives: 40}),
#           (_279:Subreddit {name: 'atheism', negatives: 2, positives: 24}),
#           (_288:Subreddit {name: 'movies', negatives: 0, positives: 5}),
#           (_291:Subreddit {name: 'defaultgems', negatives: 14, positives: 68}),
#           (_298:Subreddit {name: 'opisafag', negatives: 0, positives: 1}),
#           (_305:Subreddit {name: 'thathappened', negatives: 10, positives: 36}),
#           (_309:Subreddit {name: '49ers', negatives: 1, positives: 15}),
#           (_311:Subreddit {name: 'mensrights', negatives: 5, positives: 22}),
#           (_313:Subreddit {name: 'libertarian', negatives: 6, positives: 23}),
#           {'name': 'mildlyinteresting',
#            'negatives': 0,
#            'positives': 9},
#           (_316:Subreddit {name: 'titlegore', negatives: 0, positives: 116}),
#           (_325:Subreddit {name: 'travel', negatives: 0, positives: 4}),
#           (_328:Subreddit {name: 'hockey', negatives: 1, positives: 14}),
#           (_331:Subreddit {name: 'retiredgif', negatives: 3, positives: 76}),
#           (_341:Subreddit {name: 'worldoftanks', negatives: 0, positives: 3}),
#           (_343:Subreddit {name: 'cringe', negatives: 2, positives: 11}),
#           (_345:Subreddit {name: 'magictcg', negatives: 0, positives: 6}),
#           (_347:Subreddit {name: 'anarchism', negatives: 1, positives: 15}),
#           (_352:Subreddit {name: 'gaming', negatives: 0, positives: 39}),
#           (_353:Subreddit {name: 'dota2', negatives: 0, positives: 14}),
#           (_358:Subreddit {name: 'australia', negatives: 0, positives: 7}),
#           (_359:Subreddit {name: 'filmmakers', negatives: 0, positives: 9}),
#           (_375:Subreddit {name: 'teenagers', negatives: 1, positives: 10}),
#           (_378:Subreddit {name: 'hiphopheads', negatives: 0, positives: 7}),
#           (_385:Subreddit {name: 'conspiratard', negatives: 10, positives: 60}),
#           {'name': 'shitredditsays',
#            'negatives': 17,
#            'positives': 107},
#           (_401:Subreddit {name: 'bicycling', negatives: 0, positives: 11}),
#           (_405:Subreddit {name: 'penis', negatives: 0, positives: 1}),
#           (_406:Subreddit {name: 'polyamory', negatives: 0, positives: 3}),
#           (_409:Subreddit {name: 'canada', negatives: 0, positives: 5}),
#           (_411:Subreddit {name: 'mgtow', negatives: 0, positives: 2}),
#           {'name': 'falconsocialclub',
#            'negatives': 0,
#            'positives': 1},
#           (_415:Subreddit {name: 'adviceof', negatives: 0, positives: 20}),
#           (_424:Subreddit {name: 'pcmasterrace', negatives: 1, positives: 25}),
#           (_427:Subreddit {name: 'circlebroke', negatives: 4, positives: 5}),
#           {'name': 'mylittleandysonic1',
#            'negatives': 2,
#            'positives': 13},
#           (_444:Subreddit {name: 'bakchodi', negatives: 1, positives: 9}),
#           {'name': 'lewronggeneration',
#            'negatives': 4,
#            'positives': 16},
#           (_448:Subreddit {name: 'getmotivated', negatives: 0, positives: 6}),
#           (_453:Subreddit {name: 'austria', negatives: 0, positives: 2}),
#           {'name': 'acceptancespeech',
#            'negatives': 0,
#            'positives': 1},
#           (_461:Subreddit {name: 'philippines', negatives: 0, positives: 6}),
#           (_464:Subreddit {name: 'space', negatives: 0, positives: 4}),
#           (_469:Subreddit {name: 'berlin', negatives: 0, positives: 7}),
#           {'name': 'electronicmusic',
#            'negatives': 0,
#            'positives': 9},
#           (_480:Subreddit {name: 'cryptocurrency', negatives: 0, positives: 9}),
#           (_484:Subreddit {name: 'games', negatives: 1, positives: 15}),
#           (_485:Subreddit {name: 'murica', negatives: 8, positives: 22}),
#           (_496:Subreddit {name: 'osu', negatives: 0, positives: 3}),
#           (_500:Subreddit {name: 'music', negatives: 0, positives: 13}),
#           (_501:Subreddit {name: 'nsl', negatives: 0, positives: 6}),
#           (_507:Subreddit {name: 'mexico', negatives: 0, positives: 4}),
#           {'name': 'androidcirclejerk',
#            'negatives': 4,
#            'positives': 15},
#           {'name': 'imgoingtohellforthis',
#            'negatives': 1,
#            'positives': 9},
#           (_541:Subreddit {name: 'seahawks', negatives: 1, positives: 14}),
#           {'name': 'hiphopcirclejerk',
#            'negatives': 7,
#            'positives': 26},
#           {'name': 'anarcho_capitalism',
#            'negatives': 3,
#            'positives': 37},
#           (_558:Subreddit {name: 'chicago', negatives: 0, positives: 4}),
#           (_559:Subreddit {name: 'bodybuilding', negatives: 1, positives: 6}),
#           (_560:Subreddit {name: 'edmproduction', negatives: 0, positives: 4}),
#           (_578:Subreddit {name: 'community', negatives: 0, positives: 6}),
#           {'name': 'antiatheismwatch',
#            'negatives': 2,
#            'positives': 7},
#           (_613:Subreddit {name: 'badeconomics', negatives: 1, positives: 21}),
#           (_643:Subreddit {name: 'trueotherkin', negatives: 0, positives: 1}),
#           (_680:Subreddit {name: 'dnd', negatives: 0, positives: 5}),
#           (_685:Subreddit {name: 'bourbon', negatives: 0, positives: 5}),
#           (_697:Subreddit {name: 'rpg', negatives: 0, positives: 8}),
#           (_699:Subreddit {name: 'endlesswar', negatives: 0, positives: 3}),
#           (_706:Subreddit {name: 'intelligence', negatives: 0, positives: 2}),
#           (_717:Subreddit {name: 'france', negatives: 0, positives: 4}),
#           {'name': 'historynetwork',
#            'negatives': 0,
#            'positives': 12},
#           (_735:Subreddit {name: 'denver', negatives: 0, positives: 3}),
#           {'name': 'evenwithcontext',
#            'negatives': 5,
#            'positives': 13},
#           (_745:Subreddit {name: 'ireland', negatives: 0, positives: 9}),
#           {'name': 'tumblrinaction',
#            'negatives': 3,
#            'positives': 10},
#           (_753:Subreddit {name: 'military', negatives: 1, positives: 2}),
#           (_759:Subreddit {name: 'photography', negatives: 0, positives: 14}),
#           {'name': 'credibledefense',
#            'negatives': 0,
#            'positives': 2},
#           (_792:Subreddit {name: 'archerfx', negatives: 0, positives: 2}),
#           (_800:Subreddit {name: 'linux', negatives: 0, positives: 9}),
#           (_813:Subreddit {name: 'pka', negatives: 1, positives: 5}),
#           (_825:Subreddit {name: '3dprinting', negatives: 0, positives: 3}),
#           {'name': 'militaryconspiracy',
#            'negatives': 0,
#            'positives': 6},
#           (_829:Subreddit {name: 'northkorea', negatives: 0, positives: 2}),
#           (_839:Subreddit {name: 'gaben', negatives: 0, positives: 2}),
#           (_855:Subreddit {name: 'exmormon', negatives: 1, positives: 22}),
#           (_875:Subreddit {name: 'turkey', negatives: 0, positives: 2}),
#           (_877:Subreddit {name: 'stalkerwatch', negatives: 3, positives: 17}),
#           (_909:Subreddit {name: 'feminisms', negatives: 3, positives: 3}),
#           {'name': 'thepopcornstand',
#            'negatives': 15,
#            'positives': 29},
#           (_959:Subreddit {name: 'catholicism', negatives: 0, positives: 11}),
#           {'name': 'firstworldproblems',
#            'negatives': 0,
#            'positives': 2},
#           (_972:Subreddit {name: 'howardstern', negatives: 0, positives: 1}),
#           {'name': 'thelastairbender',
#            'negatives': 0,
#            'positives': 3},
#           (_1005:Subreddit {name: 'catiewayne', negatives: 0, positives: 1}),
#           {'name': 'linuxactionshow',
#            'negatives': 0,
#            'positives': 6},
#           (_1028:Subreddit {name: 'anonymous', negatives: 0, positives: 3}),
#           (_1029:Subreddit {name: 'writers', negatives: 0, positives: 1}),
#           (_1068:Subreddit {name: 'reddevils', negatives: 0, positives: 5}),
#           (_1086:Subreddit {name: 'rapbattles', negatives: 0, positives: 1}),
#           {'name': 'notinteresting',
#            'negatives': 0,
#            'positives': 2},
#           (_1116:Subreddit {name: 'squaredcircle', negatives: 0, positives: 8}),
#           (_1127:Subreddit {name: 'punny', negatives: 0, positives: 3}),
#           (_1131:Subreddit {name: 'joerogan', negatives: 0, positives: 6}),
#           (_1139:Subreddit {name: 'cgpgrey', negatives: 0, positives: 1}),
#           (_1152:Subreddit {name: 'dresdenfiles', negatives: 0, positives: 2}),
#           (_1175:Subreddit {name: 'psychology', negatives: 0, positives: 4}),
#           (_1180:Subreddit {name: 'guns', negatives: 0, positives: 7}),
#           (_1197:Subreddit {name: 'thesimpsons', negatives: 0, positives: 3}),
#           (_1258:Subreddit {name: 'bikecommuting', negatives: 0, positives: 3}),
#           {'name': 'opieandanthony',
#            'negatives': 0,
#            'positives': 7},
#           (_1275:Subreddit {name: 'eve', negatives: 0, positives: 8}),
#           {'name': 'metatruereddit',
#            'negatives': 0,
#            'positives': 3},
#           (_1300:Subreddit {name: 'madisonwi', negatives: 1, positives: 2}),
#           (_1310:Subreddit {name: 'minimalism', negatives: 0, positives: 2}),
#           (_1323:Subreddit {name: 'russia', negatives: 0, positives: 5}),
#           (_1325:Subreddit {name: 'futurology', negatives: 0, positives: 4}),
#           (_1332:Subreddit {name: 'oswego', negatives: 0, positives: 1}),
#           (_1383:Subreddit {name: 'superman', negatives: 0, positives: 1}),
#           (_1384:Subreddit {name: 'fantasy', negatives: 0, positives: 5}),
#           (_1399:Subreddit {name: 'google', negatives: 0, positives: 4}),
#           (_1402:Subreddit {name: 'losangeles', negatives: 0, positives: 8}),
#           (_1407:Subreddit {name: 'zenhabits', negatives: 0, positives: 1}),
#           (_1426:Subreddit {name: 'everquest', negatives: 0, positives: 3}),
#           (_1438:Subreddit {name: 'homebrewing', negatives: 0, positives: 2}),
#           (_1446:Subreddit {name: 'maximumfun', negatives: 0, positives: 2}),
#           (_1451:Subreddit {name: 'simpleliving', negatives: 0, positives: 1}),
#           {'name': 'patriciacaprice',
#            'negatives': 0,
#            'positives': 1},
#           (_1491:Subreddit {name: 'hardstyle', negatives: 0, positives: 2}),
#           (_1493:Subreddit {name: 'edm', negatives: 0, positives: 4}),
#           {'name': 'campingandhiking',
#            'negatives': 0,
#            'positives': 2},
#           {'name': 'moneylaundering',
#            'negatives': 0,
#            'positives': 1},
#           {'name': 'pacificcresttrail',
#            'negatives': 0,
#            'positives': 2},
#           (_1501:Subreddit {name: 'challenge', negatives: 0, positives: 1}),
#           (_1503:Subreddit {name: '90shiphop', negatives: 0, positives: 1}),
#           (_1507:Subreddit {name: 'progun', negatives: 1, positives: 7}),
#           (_1511:Subreddit {name: 'poker', negatives: 0, positives: 1}),
#           (_1540:Subreddit {name: 'poppunkers', negatives: 0, positives: 1}),
#           (_1543:Subreddit {name: 'firearms', negatives: 0, positives: 5}),
#           (_1556:Subreddit {name: 'lgbt', negatives: 0, positives: 6}),
#           (_1566:Subreddit {name: 'monstercat', negatives: 0, positives: 3}),
#           (_1571:Subreddit {name: 'sasquatch', negatives: 0, positives: 1}),
#           (_1574:Subreddit {name: 'automate', negatives: 0, positives: 2}),
#           (_1608:Subreddit {name: 'seagray', negatives: 0, positives: 5}),
#           {'name': 'monolithdigital',
#            'negatives': 0,
#            'positives': 2},
#           (_1641:Subreddit {name: 'tennis', negatives: 0, positives: 1}),
#           (_1668:Subreddit {name: 'topreddit', negatives: 0, positives: 3}),
#           (_1669:Subreddit {name: 'dbz', negatives: 0, positives: 2}),
#           (_1674:Subreddit {name: 'asianamerican', negatives: 0, positives: 5}),
#           (_1681:Subreddit {name: 'collapse', negatives: 1, positives: 7}),
#           (_1682:Subreddit {name: 'dieoff', negatives: 0, positives: 1}),
#           {'name': 'naturedocumentaries',
#            'negatives': 0,
#            'positives': 1},
#           {'name': 'kerbalspaceprogram',
#            'negatives': 0,
#            'positives': 6},
#           {'name': 'rollercoasters',
#            'negatives': 0,
#            'positives': 2},
#           (_1744:Subreddit {name: 'pittsburgh', negatives: 0, positives: 4}),
#           (_1748:Subreddit {name: 'oculus', negatives: 0, positives: 5}),
#           (_1767:Subreddit {name: 'nasa', negatives: 0, positives: 4}),
#           (_1866:Subreddit {name: 'lacrosse', negatives: 0, positives: 1}),
#           (_1905:Subreddit {name: 'peloton', negatives: 0, positives: 2}),
#           (_1918:Subreddit {name: 'bobsburgers', negatives: 0, positives: 1}),
#           (_1971:Subreddit {name: 'earwolf', negatives: 0, positives: 1}),
#           (_1988:Subreddit {name: 'retrogaming', negatives: 0, positives: 1}),
#           (_1999:Subreddit {name: 'yoga', negatives: 0, positives: 2}),
#           (_2019:Subreddit {name: 'entertainment', negatives: 0, positives: 1}),
#           (_2020:Subreddit {name: 'beards', negatives: 0, positives: 3}),
#           (_2032:Subreddit {name: 'clopclop', negatives: 0, positives: 1}),
#           {'name': 'kitchenconfidential',
#            'negatives': 0,
#            'positives': 3},
#           {'name': 'classicalmusic',
#            'negatives': 1,
#            'positives': 0},
#           {'name': 'thankyoubasedgod',
#            'negatives': 0,
#            'positives': 1},
#           (_2120:Subreddit {name: 'drexel', negatives: 0, positives: 1}),
#           (_2154:Subreddit {name: 'paleo', negatives: 0, positives: 3}),
#           (_2170:Subreddit {name: 'leopardgeckos', negatives: 0, positives: 1}),
#           (_2186:Subreddit {name: 'seinfeld', negatives: 0, positives: 4}),
#           (_2187:Subreddit {name: 'ubuntu', negatives: 0, positives: 2}),
#           (_2206:Subreddit {name: 'cleveland', negatives: 0, positives: 2}),
#           (_2222:Subreddit {name: 'godzilla', negatives: 0, positives: 1}),
#           {'name': 'trancecirclejerk',
#            'negatives': 0,
#            'positives': 5},
#           {'name': 'occupywallstreet',
#            'negatives': 1,
#            'positives': 4},
#           (_2261:Subreddit {name: 'fosterit', negatives: 0, positives: 1}),
#           {'name': 'daystrominstitute',
#            'negatives': 0,
#            'positives': 1},
#           (_2343:Subreddit {name: 'punk', negatives: 0, positives: 1}),
#           {'name': 'collegebasketball',
#            'negatives': 0,
#            'positives': 2},
#           (_2391:Subreddit {name: 'crohnsdisease', negatives: 0, positives: 1}),
#           (_2393:Subreddit {name: 'snowden', negatives: 0, positives: 5}),
#           {'name': 'bigdickproblems',
#            'negatives': 0,
#            'positives': 3},
#           (_2432:Subreddit {name: 'thebugle', negatives: 0, positives: 1}),
#           (_2435:Subreddit {name: 'jazz', negatives: 0, positives: 1}),
#           (_2460:Subreddit {name: 'radiohead', negatives: 0, positives: 1}),
#           (_2463:Subreddit {name: 'savant', negatives: 0, positives: 1}),
#           (_2467:Subreddit {name: 'silentnetwork', negatives: 0, positives: 1}),
#           (_2482:Subreddit {name: 'cocacola', negatives: 0, positives: 1}),
#           {'name': 'stephenmalkmus',
#            'negatives': 0,
#            'positives': 1},
#           (_2515:Subreddit {name: 'incubus', negatives: 0, positives: 1}),
#           {'name': 'universityofreddit',
#            'negatives': 0,
#            'positives': 1},
#           (_2541:Subreddit {name: 'columbia', negatives: 0, positives: 1}),
#           {'name': 'descentintotyranny',
#            'negatives': 0,
#            'positives': 1},
#           {'name': 'livefromnewyork',
#            'negatives': 0,
#            'positives': 2},
#           (_2563:Subreddit {name: 'nsaleaks', negatives: 0, positives: 1}),
#           (_2600:Subreddit {name: 'manning', negatives: 0, positives: 1}),
#           (_2653:Subreddit {name: 'tpp', negatives: 0, positives: 1}),
#           (_2655:Subreddit {name: 'enviroment', negatives: 0, positives: 1}),
#           {'name': 'wearescientists',
#            'negatives': 0,
#            'positives': 1},
#           (_2665:Subreddit {name: 'kingdomhearts', negatives: 0, positives: 1}),
#           (_2705:Subreddit {name: 'troubledteens', negatives: 0, positives: 4}),
#           (_2731:Subreddit {name: 'doublemeat', negatives: 0, positives: 1}),
#           (_2736:Subreddit {name: 'inthemorning', negatives: 0, positives: 3}),
#           (_2762:Subreddit {name: 'dumbanddumber', negatives: 0, positives: 1}),
#           (_2772:Subreddit {name: 'batman', negatives: 0, positives: 2}),
#           (_2784:Subreddit {name: 'hwstartups', negatives: 0, positives: 2}),
#           (_2787:Subreddit {name: 'polyphasic', negatives: 0, positives: 1}),
#           (_2869:Subreddit {name: 'olympics', negatives: 0, positives: 6}),
#           (_3001:Subreddit {name: 'republican', negatives: 1, positives: 2}),
#           (_3019:Subreddit {name: 'portugal', negatives: 0, positives: 4}),
#           (_3055:Subreddit {name: 'survivor', negatives: 0, positives: 1}),
#           {'name': 'abuseinterrupted',
#            'negatives': 2,
#            'positives': 1},
#           (_3063:Subreddit {name: 'insidegaming', negatives: 0, positives: 1}),
#           {'name': 'geologycareers',
#            'negatives': 0,
#            'positives': 1},
#           (_3139:Subreddit {name: 'ukraine', negatives: 1, positives: 5}),
#           {'name': 'arnoldschwarzenegger',
#            'negatives': 0,
#            'positives': 1},
#           (_3192:Subreddit {name: 'beatles', negatives: 0, positives: 1}),
#           (_3214:Subreddit {name: 'loungegrumps', negatives: 0, positives: 1}),
#           (_3222:Subreddit {name: 'guildwars2', negatives: 0, positives: 1}),
#           (_3223:Subreddit {name: 'twitchtv', negatives: 0, positives: 3}),
#           (_3244:Subreddit {name: 'machinima', negatives: 0, positives: 1}),
#           (_3247:Subreddit {name: 'gibdyk', negatives: 0, positives: 1}),
#           (_3269:Subreddit {name: 'starwarseu', negatives: 0, positives: 1}),
#           {'name': 'darkjedibrotherhood',
#            'negatives': 0,
#            'positives': 1},
#           (_3276:Subreddit {name: 'governorsball', negatives: 0, positives: 1}),
#           (_3282:Subreddit {name: 'sithit', negatives: 0, positives: 1}),
#           (_3286:Subreddit {name: 'nether', negatives: 0, positives: 1}),
#           (_3301:Subreddit {name: 'eliomotors', negatives: 0, positives: 1}),
#           {'name': 'grouptherapyradio',
#            'negatives': 0,
#            'positives': 1},
#           (_3415:Subreddit {name: 'vegas', negatives: 0, positives: 1}),
#           (_3420:Subreddit {name: 'coldallergy', negatives: 0, positives: 1}),
#           (_3424:Subreddit {name: 'tacobell', negatives: 0, positives: 1}),
#           (_3439:Subreddit {name: 'pikapp', negatives: 0, positives: 1}),
#           (_3451:Subreddit {name: 'f1circlejerk', negatives: 0, positives: 1}),
#           {'name': 'enlightenedbirdmen',
#            'negatives': 0,
#            'positives': 4},
#           (_3521:Subreddit {name: 'crusaderkings', negatives: 0, positives: 1}),
#           (_3540:Subreddit {name: 'fonts', negatives: 0, positives: 1}),
#           (_3541:Subreddit {name: 'mmorpg', negatives: 0, positives: 3}),
#           (_3567:Subreddit {name: 'harmontown', negatives: 0, positives: 2}),
#           (_3594:Subreddit {name: 'channel101', negatives: 0, positives: 1}),
#           (_3669:Subreddit {name: 'finland', negatives: 1, positives: 1}),
#           (_3678:Subreddit {name: 'armenian', negatives: 0, positives: 1}),
#           (_3692:Subreddit {name: 'iasip', negatives: 0, positives: 1}),
#           (_3713:Subreddit {name: 'adultswim', negatives: 0, positives: 4}),
#           (_3744:Subreddit {name: 'indie', negatives: 0, positives: 1}),
#           (_3745:Subreddit {name: 'themightypen', negatives: 0, positives: 1}),
#           (_3748:Subreddit {name: 'unidanfans', negatives: 0, positives: 2}),
#           {'name': 'erotichypnosis',
#            'negatives': 0,
#            'positives': 1},
#           (_3831:Subreddit {name: 'dancemoms', negatives: 0, positives: 1}),
#           (_3842:Subreddit {name: 'swimming', negatives: 0, positives: 1}),
#           (_3886:Subreddit {name: 'hamilton', negatives: 0, positives: 1}),
#           (_3906:Subreddit {name: 'bboy', negatives: 0, positives: 1}),
#           (_3932:Subreddit {name: 'timanderic', negatives: 0, positives: 1}),
#           (_3940:Subreddit {name: 'pantheonrotf', negatives: 0, positives: 1}),
#           (_3941:Subreddit {name: 'vanguard', negatives: 0, positives: 1}),
#           (_3943:Subreddit {name: 'project1999', negatives: 0, positives: 1}),
#           (_3973:Subreddit {name: 'boobies', negatives: 0, positives: 1}),
#           (_3974:Subreddit {name: 'fullhouse', negatives: 0, positives: 1}),
#           (_3975:Subreddit {name: 'boobs', negatives: 0, positives: 1}),
#           (_3978:Subreddit {name: 'clonehigh', negatives: 0, positives: 1}),
#           (_4118:Subreddit {name: 'avegantglyph', negatives: 0, positives: 1}),
#           {'name': 'vanessahudgens',
#            'negatives': 0,
#            'positives': 1},
#           (_4184:Subreddit {name: 'infamous', negatives: 0, positives: 1})],
#  'pics': [(_149:Subreddit {name: 'depthhub', negatives: 8, positives: 53}),
#           {'name': 'fitnesscirclejerk',
#            'negatives': 19,
#            'positives': 87},
#           {'name': 'quityourbullshit',
#            'negatives': 14,
#            'positives': 22},
#           (_172:Subreddit {name: 'bestof', negatives: 101, positives: 494}),
#           (_175:Subreddit {name: 'funny', negatives: 1, positives: 19}),
#           (_181:Subreddit {name: 'switcharoo', negatives: 5, positives: 115}),
#           (_183:Subreddit {name: 'bitcoin', negatives: 2, positives: 48}),
#           {'name': 'subredditdrama',
#            'negatives': 216,
#            'positives': 360},
#           (_188:Subreddit {name: 'propaganda', negatives: 0, positives: 2}),
#           (_189:Subreddit {name: 'conspiracy', negatives: 5, positives: 56}),
#           (_196:Subreddit {name: 'agitation', negatives: 8, positives: 53}),
#           (_212:Subreddit {name: 'circlebroke2', negatives: 27, positives: 74}),
#           (_213:Subreddit {name: 'trees', negatives: 0, positives: 29}),
#           {'name': 'examplesofevil',
#            'negatives': 0,
#            'positives': 33},
#           (_228:Subreddit {name: 'todayilearned', negatives: 6, positives: 32}),
#           (_237:Subreddit {name: 'india', negatives: 1, positives: 21}),
#           {'name': 'shitstatistssay',
#            'negatives': 17,
#            'positives': 93},
#           {'name': 'shitamericanssay',
#            'negatives': 14,
#            'positives': 71},
#           (_254:Subreddit {name: 'videos', negatives: 0, positives: 6}),
#           (_260:Subreddit {name: 'philosophy', negatives: 0, positives: 3}),
#           {'name': 'protectandserve',
#            'negatives': 1,
#            'positives': 6},
#           (_262:Subreddit {name: 'aww', negatives: 0, positives: 5}),
#           (_269:Subreddit {name: 'dogecoin', negatives: 3, positives: 94}),
#           (_276:Subreddit {name: 'metacanada', negatives: 5, positives: 40}),
#           (_278:Subreddit {name: 'notcirclejerk', negatives: 0, positives: 40}),
#           (_291:Subreddit {name: 'defaultgems', negatives: 14, positives: 68}),
#           (_305:Subreddit {name: 'thathappened', negatives: 10, positives: 36}),
#           (_311:Subreddit {name: 'mensrights', negatives: 5, positives: 22}),
#           {'name': 'karmaconspiracy',
#            'negatives': 6,
#            'positives': 18},
#           (_316:Subreddit {name: 'titlegore', negatives: 0, positives: 116}),
#           (_318:Subreddit {name: 'danmag', negatives: 0, positives: 15}),
#           (_331:Subreddit {name: 'retiredgif', negatives: 3, positives: 76}),
#           (_338:Subreddit {name: 'gmomyths', negatives: 13, positives: 23}),
#           {'name': 'badlinguistics',
#            'negatives': 5,
#            'positives': 48},
#           (_377:Subreddit {name: 'socialism', negatives: 1, positives: 8}),
#           (_385:Subreddit {name: 'conspiratard', negatives: 10, positives: 60}),
#           {'name': 'shitredditsays',
#            'negatives': 17,
#            'positives': 107},
#           (_389:Subreddit {name: 'woahdude', negatives: 0, positives: 7}),
#           (_406:Subreddit {name: 'polyamory', negatives: 0, positives: 3}),
#           {'name': 'drugscirclejerk',
#            'negatives': 5,
#            'positives': 11},
#           (_415:Subreddit {name: 'adviceof', negatives: 0, positives: 20}),
#           (_416:Subreddit {name: 'books', negatives: 0, positives: 12}),
#           {'name': 'shitpoliticssays',
#            'negatives': 1,
#            'positives': 14},
#           (_427:Subreddit {name: 'circlebroke', negatives: 4, positives: 5}),
#           (_475:Subreddit {name: 'beyondthebump', negatives: 1, positives: 3}),
#           (_484:Subreddit {name: 'games', negatives: 1, positives: 15}),
#           (_518:Subreddit {name: 'carcrash', negatives: 0, positives: 2}),
#           (_530:Subreddit {name: 'verypunny', negatives: 0, positives: 5}),
#           (_531:Subreddit {name: 'shitpost', negatives: 3, positives: 29}),
#           {'name': 'imgoingtohellforthis',
#            'negatives': 1,
#            'positives': 9},
#           (_540:Subreddit {name: 'phish', negatives: 0, positives: 5}),
#           {'name': 'whatsinthisthing',
#            'negatives': 0,
#            'positives': 1},
#           (_556:Subreddit {name: 'lotr', negatives: 0, positives: 5}),
#           (_559:Subreddit {name: 'bodybuilding', negatives: 1, positives: 6}),
#           (_574:Subreddit {name: 'hey_look_at_me', negatives: 0, positives: 4}),
#           {'name': 'weddingplanning',
#            'negatives': 0,
#            'positives': 2},
#           {'name': 'goldredditsays',
#            'negatives': 6,
#            'positives': 24},
#           (_600:Subreddit {name: 'vietnam', negatives: 0, positives: 1}),
#           (_609:Subreddit {name: 'worstof', negatives: 3, positives: 15}),
#           {'name': 'mechanicalkeyboards',
#            'negatives': 0,
#            'positives': 3},
#           (_615:Subreddit {name: 'waitingforop', negatives: 0, positives: 3}),
#           (_619:Subreddit {name: 'teenguide', negatives: 0, positives: 9}),
#           {'name': 'wtfdidijustread',
#            'negatives': 3,
#            'positives': 16},
#           (_635:Subreddit {name: 'drama', negatives: 4, positives: 7}),
#           (_640:Subreddit {name: 'buddhism', negatives: 0, positives: 8}),
#           {'name': 'examplesofgood',
#            'negatives': 0,
#            'positives': 13},
#           (_648:Subreddit {name: 'jacksonville', negatives: 0, positives: 2}),
#           (_658:Subreddit {name: 'slp', negatives: 1, positives: 1}),
#           (_661:Subreddit {name: 'historyporn', negatives: 0, positives: 1}),
#           (_665:Subreddit {name: 'botsscrewingup', negatives: 0, positives: 3}),
#           (_679:Subreddit {name: 'autowikibot', negatives: 0, positives: 4}),
#           {'name': 'evenwithcontext',
#            'negatives': 5,
#            'positives': 13},
#           (_759:Subreddit {name: 'photography', negatives: 0, positives: 14}),
#           (_773:Subreddit {name: 'theredpill', negatives: 3, positives: 7}),
#           (_798:Subreddit {name: 'jurassicpark', negatives: 0, positives: 2}),
#           (_825:Subreddit {name: '3dprinting', negatives: 0, positives: 3}),
#           {'name': 'horriblydepressing',
#            'negatives': 1,
#            'positives': 2},
#           {'name': 'militaryconspiracy',
#            'negatives': 0,
#            'positives': 6},
#           (_844:Subreddit {name: 'epu', negatives: 0, positives: 11}),
#           (_858:Subreddit {name: 'houston', negatives: 0, positives: 5}),
#           (_874:Subreddit {name: 'web_design', negatives: 0, positives: 2}),
#           (_887:Subreddit {name: 'fortporn', negatives: 0, positives: 1}),
#           (_927:Subreddit {name: 'treknobabble', negatives: 0, positives: 13}),
#           (_967:Subreddit {name: 'swarje', negatives: 1, positives: 8}),
#           (_974:Subreddit {name: 'fallout', negatives: 0, positives: 6}),
#           (_989:Subreddit {name: 'no_sob_story', negatives: 0, positives: 1}),
#           (_1027:Subreddit {name: 'retiredjpg', negatives: 0, positives: 7}),
#           (_1162:Subreddit {name: 'outside', negatives: 0, positives: 5}),
#           (_1169:Subreddit {name: 'morbidreality', negatives: 0, positives: 6}),
#           {'name': 'shitredditgilds',
#            'negatives': 0,
#            'positives': 9},
#           (_1197:Subreddit {name: 'thesimpsons', negatives: 0, positives: 3}),
#           (_1215:Subreddit {name: 'teslamotors', negatives: 1, positives: 1}),
#           {'name': 'whowillbuildtheroads',
#            'negatives': 0,
#            'positives': 7},
#           {'name': 'picsofmenwiththings',
#            'negatives': 0,
#            'positives': 2},
#           (_1275:Subreddit {name: 'eve', negatives: 0, positives: 8}),
#           (_1281:Subreddit {name: 'redditdads', negatives: 0, positives: 6}),
#           (_1323:Subreddit {name: 'russia', negatives: 0, positives: 5}),
#           (_1379:Subreddit {name: 'indonesia', negatives: 0, positives: 4}),
#           {'name': 'shittylifeprotips',
#            'negatives': 0,
#            'positives': 1},
#           (_1411:Subreddit {name: 'baltimore', negatives: 0, positives: 4}),
#           (_1520:Subreddit {name: 'teachers', negatives: 0, positives: 2}),
#           (_1612:Subreddit {name: 'kratom', negatives: 0, positives: 1}),
#           (_1637:Subreddit {name: 'freedomearth', negatives: 0, positives: 3}),
#           (_1694:Subreddit {name: 'ubreddit', negatives: 0, positives: 2}),
#           (_1732:Subreddit {name: 'romania', negatives: 0, positives: 8}),
#           (_1760:Subreddit {name: 'flipping', negatives: 1, positives: 2}),
#           (_1767:Subreddit {name: 'nasa', negatives: 0, positives: 4}),
#           (_1769:Subreddit {name: 'charlotte', negatives: 0, positives: 1}),
#           (_1780:Subreddit {name: 'infographics', negatives: 0, positives: 1}),
#           (_1835:Subreddit {name: 'austin', negatives: 0, positives: 3}),
#           (_1841:Subreddit {name: 'connecticut', negatives: 0, positives: 3}),
#           (_1854:Subreddit {name: 'thehobbit', negatives: 0, positives: 2}),
#           (_1857:Subreddit {name: 'italy', negatives: 0, positives: 4}),
#           (_1865:Subreddit {name: 'oldschoolcool', negatives: 0, positives: 1}),
#           (_1932:Subreddit {name: 'louisville', negatives: 0, positives: 2}),
#           {'name': 'guildwars2funny',
#            'negatives': 0,
#            'positives': 1},
#           (_2127:Subreddit {name: 'drwho', negatives: 0, positives: 1}),
#           (_2164:Subreddit {name: 'lexington', negatives: 0, positives: 1}),
#           {'name': 'cinnamontitties',
#            'negatives': 0,
#            'positives': 1},
#           (_2266:Subreddit {name: 'trains', negatives: 0, positives: 1}),
#           {'name': 'shittyfoodporn',
#            'negatives': 0,
#            'positives': 1},
#           (_2358:Subreddit {name: 'judaism', negatives: 0, positives: 8}),
#           {'name': 'bigdickproblems',
#            'negatives': 0,
#            'positives': 3},
#           (_2592:Subreddit {name: 'bugs', negatives: 0, positives: 1}),
#           (_2740:Subreddit {name: 'puzzles', negatives: 0, positives: 2}),
#           (_2801:Subreddit {name: 'arrow', negatives: 0, positives: 1}),
#           (_2808:Subreddit {name: 'discgolf', negatives: 0, positives: 2}),
#           (_2886:Subreddit {name: 'funfacts', negatives: 0, positives: 2}),
#           (_2903:Subreddit {name: 'jaihind', negatives: 0, positives: 1}),
#           {'name': 'justneckbeardthings',
#            'negatives': 0,
#            'positives': 3},
#           {'name': 'computergraphics',
#            'negatives': 0,
#            'positives': 1},
#           (_3010:Subreddit {name: 'bioshock', negatives: 0, positives: 2}),
#           {'name': 'stormlight_archive',
#            'negatives': 0,
#            'positives': 3},
#           (_3135:Subreddit {name: 'sodastream', negatives: 0, positives: 1}),
#           (_3139:Subreddit {name: 'ukraine', negatives: 1, positives: 5}),
#           (_3144:Subreddit {name: 'pedale', negatives: 0, positives: 1}),
#           (_3189:Subreddit {name: 'toosoon', negatives: 0, positives: 2}),
#           {'name': 'retiredusername',
#            'negatives': 0,
#            'positives': 3},
#           (_3240:Subreddit {name: 'iwallpaper', negatives: 0, positives: 1}),
#           {'name': 'nativeamerican',
#            'negatives': 0,
#            'positives': 3},
#           {'name': 'oregonstateuniv',
#            'negatives': 0,
#            'positives': 2},
#           (_3362:Subreddit {name: 'nyto', negatives: 0, positives: 2}),
#           {'name': 'musculardystrophy',
#            'negatives': 0,
#            'positives': 1},
#           (_3629:Subreddit {name: 'bears', negatives: 0, positives: 1}),
#           (_3696:Subreddit {name: 'suchsubreddit', negatives: 0, positives: 1}),
#           {'name': 'theplaceforthestuff',
#            'negatives': 0,
#            'positives': 1},
#           (_3768:Subreddit {name: 'herons', negatives: 0, positives: 1}),
#           (_3838:Subreddit {name: 'welding', negatives: 0, positives: 1}),
#           {'name': 'montgomerycountymd',
#            'negatives': 0,
#            'positives': 1},
#           (_3867:Subreddit {name: 'hoco', negatives: 0, positives: 1}),
#           {'name': 'anonymousphilosophy',
#            'negatives': 0,
#            'positives': 1},
#           (_4031:Subreddit {name: 'tinyhouses', negatives: 0, positives: 1}),
#           (_4089:Subreddit {name: 'bih', negatives: 0, positives: 1}),
#           (_4103:Subreddit {name: 'serbia', negatives: 0, positives: 1}),
#           (_4275:Subreddit {name: 'unitinu', negatives: 0, positives: 1}),
#           (_4323:Subreddit {name: 'hoggit', negatives: 0, positives: 1})]}

# %% [markdown]
# <img src="subreddits mas referenciados.png">

# %% [markdown]
# > ### 3) Considerando el atributo POST_LABEL, estudiar un caso donde una comunidad se refiera negativamente de otra.

# %% [markdown]
# Utilizando la siguiente consulta, se pueden tener ejemplos de comunidades a las cuales se han referido más de manera negativa que positiva:

# %%
query = """
match (n:Subreddit)-[:REFERENCE]->(m)
where n.positives < n.negatives
return m, collect(n) as subr
order by size(subr) desc limit 3
"""

data = graph.run(query)

subreddit_names = []
for d in data:
    print(d)
# Out:
# <Record m=(_199:Subreddit {name: 'askreddit', negatives: 20, positives: 124}) subr=[(_756:Subreddit {name: 'muhfeelings', negatives: 3, positives: 2}), (_956:Subreddit {name: 'itcrowd', negatives: 1, positives: 0}), (_1229:Subreddit {name: 'trueatheism', negatives: 4, positives: 2}), (_1642:Subreddit {name: 'toasterrights', negatives: 2, positives: 0}), (_1810:Subreddit {name: 'divorce', negatives: 1, positives: 0}), (_1833:Subreddit {name: 'mdma', negatives: 1, positives: 0}), (_1986:Subreddit {name: 'mynextband', negatives: 3, positives: 2}), (_2406:Subreddit {name: 'twobestfriendsplay', negatives: 1, positives: 0}), (_2949:Subreddit {name: 'antimemewatch', negatives: 3, positives: 0}), (_3492:Subreddit {name: '19thworldproblems', negatives: 1, positives: 0}), (_4863:Subreddit {name: 'entwives', negatives: 2, positives: 1}), (_5292:Subreddit {name: 'rayromano', negatives: 1, positives: 0}), (_5492:Subreddit {name: 'singing', negatives: 1, positives: 0}), (_6314:Subreddit {name: 'massage', negatives: 1, positives: 0})]>
# <Record m=(_1804:Subreddit {name: 'newhampshire', negatives: 0, positives: 1}) subr=[(_2672:Subreddit {name: 'callflood', negatives: 1, positives: 0}), (_2674:Subreddit {name: 'legalizeit', negatives: 1, positives: 0}), (_2675:Subreddit {name: 'freestateproject', negatives: 1, positives: 0}), (_2682:Subreddit {name: 'occupyboston', negatives: 1, positives: 0}), (_2686:Subreddit {name: 'treesactivism', negatives: 1, positives: 0}), (_2687:Subreddit {name: 'timetolegalize', negatives: 1, positives: 0}), (_2689:Subreddit {name: 'project420', negatives: 1, positives: 0}), (_2707:Subreddit {name: 'facebookactivism', negatives: 1, positives: 0})]>
# <Record m=(_158:Subreddit {name: 'wtf', negatives: 1, positives: 7}) subr=[(_756:Subreddit {name: 'muhfeelings', negatives: 3, positives: 2}), (_979:Subreddit {name: 'walmart', negatives: 1, positives: 0}), (_1460:Subreddit {name: 'equestrian', negatives: 1, positives: 0}), (_3003:Subreddit {name: 'jetta', negatives: 1, positives: 0}), (_3868:Subreddit {name: 'circlebroken', negatives: 2, positives: 1})]>

# %% [markdown]
# <img src='subredits negativos.png'>
